# %%
from Ko import *
import pandas as pd

# %% [markdown]
# # 크롤링 수행

# %%
keyword = '삼성전자'

my_crawler = NaverNewsCrawler(keyword)
temp_dict = my_crawler.crawl_process(n_page= 400)

# %%
try :
    data_df = pd.read_csv('Data/Samsung.csv', encoding = 'cp949')
except:
    data_df = my_crawler.data
data_df.head()
# Out:
#                                   title  \
# 0                 삼성전자 미국서 PC 품질 신뢰도 1위
# 1     2천590만원짜리 TV…삼성전자 QLED 8K 사전판매 돌입
# 2  가장 고장없는 PC…삼성전자 미국서 품질 신뢰도 1위 브랜드 등극
# 3                  C랩 관리에서 창의로 삼성문화 바꿨다
# 4      삼성전자 풀HD 16배 화소 QLED 8K 국내 판매 시작
#
#                                                 text      date publisher  \
# 0  삼성전자 노트북 ‘노트북Pen’ - 레스큐컴 ‘컴퓨터 신뢰 보고서’ - 삼성 신뢰도...  20181018     헤럴드경제
# 1  UHD 4배 수준 3천300만개 화소…'초고화질 전환 AI엔진' 등 탑재 삼성전자,...  20181018      연합뉴스
# 2  삼성전자, 미국서 품질 신뢰도 1위. 사진은 이날 오전 서울 서초구 삼성딜라이트 모...  20181018      경인일보
# 3  삼성전자-서울대 공동연구소에 위치한 C랩 라운지에서 C랩 과제원들이 아이디어를 교류...  20181018      내일신문
# 4  삼성전자 모델들이 서울 삼성디지털프라자 학여울점에서 퀀텀닷 기술에 8K 해상도를 적...  20181018       더팩트
#
#   keyword
# 0      신뢰
# 1    qled
# 2      미국
# 3     아이콘
# 4    qled

# %% [markdown]
# # 데이터 전처리

# %%
my_nlp = NLP()
# Out:
# C:\Users\Dong\AppData\Local\Continuum\anaconda3\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
tf_idf_df, first_keyword_ls, second_keyword_ls = my_nlp.make_tf_idf_df(data_df['text'], 
                                                                       min_df = 2,
                                                                       max_df=  0.2,
                                                                       if_nown= False)
# Out:
# 3404

# %%
Counter(first_keyword_ls).most_common(10)
# Out:
# [('브랜드', 86),
#  ('메탈', 44),
#  ('청년', 39),
#  ('지랩스', 37),
#  ('경기도', 37),
#  ('협력', 37),
#  ('퍼스트', 35),
#  ('트래픽', 33),
#  ('인도네시아', 33),
#  ('텔레콤', 28)]

# %%
Counter(second_keyword_ls).most_common(10)
# Out:
# [('갤럭시', 43),
#  ('소프트웨어', 39),
#  ('브랜드', 38),
#  ('sk', 35),
#  ('지랩스', 34),
#  ('글로벌', 33),
#  ('색상', 30),
#  ('상용', 26),
#  ('카메라', 23),
#  ('tv', 22)]

# %%
data_df.loc[2,'text']
# Out:
# '삼성전자, 미국서 품질 신뢰도 1위. 사진은 이날 오전 서울 서초구 삼성딜라이트 모습. /연합뉴스 삼성전자가 미국에서 고장이 가장 없는 데스크탑·노트북 PC 브랜드로 꼽혔다. 18일 업계에 따르면 미국의 컴퓨터...'

# %%
tf_idf_df.loc[2].sort_values(ascending = False)[:5]
# Out:
# 미국      0.398571
# 고장      0.264483
# 데스크탑    0.264483
# 신뢰      0.264483
# 컴퓨터     0.259049
# Name: 2, dtype: float64

# %%
data_df['1st_keyword'] = first_keyword_ls
data_df['2nd_keyword'] = second_keyword_ls
data_df.head(30)
# Out:
#                                           title  \
# 7   최신 반도체 시장 흐름·첨단기술 트렌드 공유 17일  삼성전자가 미국 실리콘밸리에서...  20181018         매일경제
# 8   삼성전자와 삼성전기가 5G 통신의 보급 확대로 통신장비와 스마트폰 부품 공급을 늘리...  20181018      비즈니스포스트
# 9   신입공채 일정 3번째 겹쳐 반도체 인력난에 양 사간 핵심인재 확보 눈치 싸움 응시생...  20181018        아시아경제
# 10  최근 삼성전자와 LG전자의 모바일 결제 서비스 전략이 상반된 모습을 보이고 있다. ...  20181018         조선비즈
# 11  삼성전자-서울대 공동연구소에 위치한 C랩 라운지에서 C랩 과제원들이 아이디어를 교류...  20181018         내일신문
# 12   삼성전자가 'QLED 8K' 65형·75형·82형·85형 4개 모델의 국내 본격 ...  20181018         연합뉴스
# 13  여러 번 얘기했지만 이재용 부회장이 삼성을 승계해야 되는데, 핵심인 삼성전자를 지배...  20181018     tbs 교통방송
# 14  "최근 SBS 보도에 따르면 2011년 2월 국세청이 삼성에버랜드 세무조사 시 4천...  20181018         논객닷컴
# 15  美 실리콘밸리서 '삼성 테크 데이 2018' 개최 세계 최초 256GB 3DS RD...  20181018         한국경제
# 16  ◆ 분석 요약 ◆ 기업 요약 2011년에 설립된 삼성그룹 계열사로 삼성물산과 삼성전...  20181018       한국경제TV
# 17  17일  삼성전자가 미국 실리콘밸리에서 주최한 '삼성 테크 데이 2018'에서 미주...  20181018       디지털데일리
# 18  최신 반도체 시장 흐름·첨단기술 트렌드 공유 17일  삼성전자가 미국 실리콘밸리에서...  20181018         매일경제
# 19  ▲ 김용 경기도 대변인이 17일 오전 경기도청 브리핑룸에서 삼성전자 이산화탄소 누출...  20181018         인천일보
# 20   17일 미국 실리콘밸리에서 열린 '삼성 테크 데이 2018'에서 삼성전자 미주 지...  20181018         연합뉴스
# 21  23일 경기도 삼성전자 화성캠퍼스에서 열린 '화성 EUV 라인 기공식'에서 참석자들...  20181018          뉴스1
# 22  업계에서는 7나노미터 EUV 공정 양산에 나선 삼성전자가 내년에도 EUV 장비를 대...  20181018      디지털데일리
# 23  삼성전자가 17일 미국 실리콘밸리서 차세대 반도체 솔루션을 공개했다. 삼성전자가 이...  20181018         경향신문
# 24   삼성전자가 장초반 약세다. 18일 오전 9시 17분 현재 삼성전자는 전거래일대비 ...  20181018      글로벌이코노믹
# 25  17일 미국 실리콘밸리에 위치한 삼성전자 미주법인 사옥에서 열린 '삼성 테크 데이 ...  20181018          뉴스1
# 26  한편 삼성전자는 평균 연봉 4300만원으로 14위를 차지했다. 성별 평균 연봉은 남...  20181018         이투데이
# 27  17일  삼성전자가 미국 실리콘밸리에서 주최한 '삼성 테크 데이 2018'에서 미주...  20181018      디지털데일리
# 28  하반기 GSAT 전형에 해당되는 삼성 계열사는 삼성전자·삼성디스플레이·삼성전기·삼성...  20181018       아시아타임즈
# 29  또 주주인 삼성전자와 삼성물산, 제일모직, 퀸타일스 등 4개사가 콜옵션 정보를 알고...  20181018  ZDNet Korea
#
#    keyword 1st_keyword 2nd_keyword
# 0       신뢰          신뢰         노트북
# 1     qled        qled         uhd
# 2       미국          미국        데스크탑
# 3      아이콘         아이콘          한지
# 4     qled        qled          모델
# 5       기술          기술       rdimm
# 6       진화          진화          주최
# 7       공유          공유        하고있다
# 8       통신          통신         김동원
# 9       일정          일정          공채
# 10      lg          lg          페이
# 11     아이콘         아이콘          한지
# 12    qled        qled          판매
# 13     되는데         되는데          해야
# 14      상당          상당          여원
# 15      기술          기술       rdimm
# 16     있으며          요약         국내외
# 17      진화          진화          주최
# 18      공유          공유        하고있다
# 19      도청          도청         대변인
# 20    2018        2018          놀까
# 21      화성          화성          가동
# 22     euv         euv        나노미터
# 23   실리콘밸리       실리콘밸리          미국
# 24      4만          4만          거래
# 25      미주          미주        하고있다
# 26      연봉          연봉          평균
# 27      노광          노광          부가
# 28      계열          계열          개사
# 29      직스          직스         바이오

# %%
data_df.loc[data_df['keyword'] == '브랜드'].head(10)
# Out:
#                                           title  \
# 576               에이스침대삼성전자 손잡고 하이마트쇼핑몰서 콜라보 행사
# 597             에이스침대 삼성전자와 콜라보 행사 롯데하이마트몰에서 진행
# 933         삼성전자 차량용 반도체 브랜드 엑시노스 오토·아이소셀 오토 출시
# 944         삼성전자 차량용 반도체 브랜드 엑시노스 오토·아이소셀 오토 출시
# 952      모바일 넘어 자동차까지…삼성전자 차량용 반도체 ‘엑시노스오토’·‘아이
# 1189  브랜드가치 세계 6위 삼성전자 사회적 책임은 64위…LG에 국내 1위 연속
# 1190  브랜드가치 세계 6위 삼성전자 사회적 책임은 64위…LG에 국내 1위 연속
# 2928                삼성전자 브랜드 가치 사상최대 599억 달러 기록
# 2935                삼성전자 브랜드 가치 사상최대 599억 달러 기록
# 2944                삼성전자 브랜드 가치 사상최대 599억 달러 기록
#
#                                                    text      date publisher  \
# 576   대한민국 대표 침대 브랜드인 에이스침대는 10월 혼수 장만을 고민하는 신혼부부를 위...  20181017       뉴스1
# 597   대한민국 대표 침대 브랜드인 에이스침대가 10월 혼수 장만을 고민하는 신혼부부를 위...  20181017    파이낸셜뉴스
# 933   삼성전자 차량용 반도체 브랜드 엑시노스 오토 이미지컷.ⓒ삼성전자차량용 반도체 브랜드...  20181016      데일리안
# 944   삼성전자 차량용 반도체 브랜드 Exynos Auto 이미지컷. 사진 = 삼성전자 제...  20181016       MTN
# 952    삼성전자 차량용 반도체 브랜드 Exynos Auto. / 삼성전자삼성전자가 차량용...  20181016      위키트리
# 1189   인터브랜드 발표 '2018 글로벌 브랜드'에서 세계 6위를 기록한 삼성전자가 지난...  20181015     업다운뉴스
# 1190   인터브랜드 발표 '2018 글로벌 브랜드'에서 세계 6위를 기록한 삼성전자가 지난...  20181015     업다운뉴스
# 2928  브랜드가치는 상승, 순위는 지난해와 동일  삼성전자가 최근 글로벌 브랜드 컨설팅 전...  20181007   인더스트리뉴스
# 2935  브랜드가치는 상승, 순위는 지난해와 동일  삼성전자가 최근 글로벌 브랜드 컨설팅 전...  20181007   인더스트리뉴스
# 2944  브랜드가치는 상승, 순위는 지난해와 동일  삼성전자가 최근 글로벌 브랜드 컨설팅 전...  20181007   인더스트리뉴스
#
#      keyword
# 576      브랜드
# 597      브랜드
# 933      브랜드
# 944      브랜드
# 952      브랜드
# 1189     브랜드
# 1190     브랜드
# 2928     브랜드
# 2935     브랜드
# 2944     브랜드

# %%
documents = my_nlp.extract_nowns_for_each_document(data_df['text'])

# %%
from collections import Counter

K = 5 

# 각 토픽이 각 문서에 할당되는 횟수
# Counter로 구성된 리스트
# 각 Counter는 각 문서를 의미
document_topic_counts = [Counter() for _ in documents]

# 각 단어가 각 토픽에 할당되는 횟수
# Counter로 구성된 리스트
# 각 Counter는 각 토픽을 의미
topic_word_counts = [Counter() for _ in range(K)]

# 각 토픽에 할당되는 총 단어수
# 숫자로 구성된 리스트
# 각각의 숫자는 각 토픽을 의미함
topic_counts = [0 for _ in range(K)]

# 각 문서에 포함되는 총 단어수
# 숫자로 구성된 리스트
# 각각의 숫자는 각 문서를 의미함
document_lengths = list(map(len, documents))

# 단어 종류의 수
distinct_words = set(word for document in documents for word in document)
V = len(distinct_words)

# 총 문서의 수
D = len(documents)

# %%
def p_topic_given_document(topic, d, alpha=0.1):
    # 문서 d의 모든 단어 가운데 topic에 속하는
    # 단어의 비율 (alpha를 더해 smoothing)
    return ((document_topic_counts[d][topic] + alpha) /
            (document_lengths[d] + K * alpha))

def p_word_given_topic(word, topic, beta=0.1):
    # topic에 속한 단어 가운데 word의 비율
    # (beta를 더해 smoothing)
    return ((topic_word_counts[topic][word] + beta) /
            (topic_counts[topic] + V * beta))

def topic_weight(d, word, k):
    # 문서와 문서의 단어가 주어지면
    # k번째 토픽의 weight를 반환
    return p_word_given_topic(word, k) * p_topic_given_document(k, d)

# %%
def choose_new_topic(d, word):
    return sample_from([topic_weight(d, word, k) for k in range(K)])

import random
def sample_from(weights):
    # i를 weights[i] / sum(weights)
    # 확률로 반환
    total = sum(weights)
    # 0과 total 사이를 균일하게 선택
    rnd = total * random.random()
    # 아래 식을 만족하는 가장 작은 i를 반환
    # weights[0] + ... + weights[i] >= rnd
    for i, w in enumerate(weights):
        rnd -= w
        if rnd <= 0:
            return i

# %%
random.seed(0)

# topic 수 지정
K = 5

# 각 단어를 임의의 토픽에 랜덤 배정
document_topics = [[random.randrange(K) for word in document]
                    for document in documents]

# 위와 같이 랜덤 초기화한 상태에서 
# AB를 구하는 데 필요한 숫자를 세어봄
for d in range(D):
    for word, topic in zip(documents[d], document_topics[d]):
        document_topic_counts[d][topic] += 1
        topic_word_counts[topic][word] += 1
        topic_counts[topic] += 1

# %%
for iter in range(1000):
    for d in range(D):
        for i, (word, topic) in enumerate(zip(documents[d],
                                              document_topics[d])):
            # 깁스 샘플링 수행을 위해
            # 샘플링 대상 word와 topic을 제외하고 세어봄
            document_topic_counts[d][topic] -= 1
            topic_word_counts[topic][word] -= 1
            topic_counts[topic] -= 1
            document_lengths[d] -= 1

            # 깁스 샘플링 대상 word와 topic을 제외한 
            # 말뭉치 모든 word의 topic 정보를 토대로
            # 샘플링 대상 word의 새로운 topic을 선택
            new_topic = choose_new_topic(d, word)
            document_topics[d][i] = new_topic

            # 샘플링 대상 word의 새로운 topic을 반영해 
            # 말뭉치 정보 업데이트
            document_topic_counts[d][new_topic] += 1
            topic_word_counts[new_topic][word] += 1
            topic_counts[new_topic] += 1
            document_lengths[d] += 1

# %%
V
# Out:
# 4322

# %%
D
# Out:
# 4000
