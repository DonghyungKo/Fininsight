# %%
import time
from selenium import webdriver
import pandas as pd
import re
import datetime
from collections import OrderedDict

# %%
class NaverNewsCrawler(object):
    
    '''
    입력한 키워드로 검색한 뉴스를 크롤링하는 클래스입니다.
    제목, 본문요약, 등록일, 언론사명를 기록합니다.
    '''
    
    
    def __init__(self, keyword):
        
        self.keyword = keyword
        self.now = datetime.datetime.now()

        self.item = OrderedDict(\
                       {'title' : [],
                        'text' : [],
                        'date' : [],
                        'publisher' : []
                       })
        
        
        # ?분 전, ?시간 전, ?일 전으로 표시되는 날짜를 정확히 계산하기 위한 정규표현식
        self.p_today = re.compile('.시간|.분')
        self.p_days_age = re.compile('.일 전')
        self.p_date = re.compile('[0-9]*\.[0-9]*\.[0-9]*')
        
        
        # Driver 열기
        path = "D:\chromedriver.exe"
        self.driver = webdriver.Chrome(path)
        self.driver.get("https://search.naver.com/search.naver?where=news&sm=tab_jum&query=%s"%keyword)
        time.sleep(3)
        
        
    
    
    
    
    # 크롤링한 title에서 특수문자를 제거하는 함수입니다.
    def _clean_title(self,text):
        text = re.sub('[\{\}\[\]\/?.,;:|\)*~`!^\-_+<>@\#$%&\\\=\(\'\"]', '' , text)
        return text
    
    
    
    
    
    
    # 크롤링한 text에서 불필요한 부분들을 제거하는 함수입니다.
    def _clean_text(self,text):
        
        # () 와 []로 감싸진 부분들은 전부 제거
        text = re.sub('\(.+?\)', '',string = text)
        text = re.sub('\[.+?\]', '',string = text)
        text = re.sub('◀.+?▶', '',string = text)
        text = re.sub('[\{\}\[\]\/?.,;:|\)*~`!^\-_+<>@\#$%&\\\=\(\'\"]▲', '' , text) # 특수문자 제거
        text = re.sub('... 기자', '', text)   # 기자라는 단어도 제거
        
        return text
        
        
        
        
        
    # 크롤링한 날짜를 YYYYmmdd 형식으로 반환하는 함수입니다.
    def _clean_date(self, text):
        
        # ?분 전, ?시간 전으로 표시되어 있다면 오늘 날짜로 치환
        if self.p_today.search(text):
            date = self.now.strftime("%Y%m%d")
        
        # ?일 전으로 표시되어 있다면 n일 전의 날짜로 치환
        elif self.p_days_age.search(text):
            n = self.p_days_age.search(text).group()[0] # n일 전의 n을 추출
            
            date = self.now - datetime.timedelta(days = int(n))
            date = date.strftime("%Y%m%d")
            
        else:
            date = self.p_date.search(text).group().replace('.','')
            
        return date
            
        
        
        
        
    # 크롤링한 publisher에서 불필요한 단어들을 제거하는 함수입니다.
    def _clean_publisher(self, text):
        return text.replace('언론사', '').replace('선정', '').replace('  ', '')
    
    
    
    
    
    
    
    
    
    # 타이틀을 크롤링하는 함수입니다.
    def _crawl_title(self):
        title_ls = [self._clean_title(title.text) for title in self.driver.find_elements_by_class_name(' _sp_each_title')]
        return title_ls
        
        
    # 본문 요약(text)을 크롤링하는 함수입니다.
    def _crawl_text(self):
        text_ls = [self._clean_text(text.text) for text in self.driver.find_elements_by_css_selector('dl > dd:nth-child(3)') if not text.text == '']
        return text_ls
    
    
    # 날짜를 크롤링하는 함수입니다.
    def _crawl_date(self):
        date_ls = [self._clean_date(date.text) for date in self.driver.find_elements_by_css_selector('dl > dd.txt_inline')]
        return date_ls
        
        
    # 언론사명를 크롤링하는 함수입니다.
    def _crawl_publisher(self):
        publisher_ls = [self._clean_publisher(title.text) for title in self.driver.find_elements_by_class_name(' _sp_each_source')]
        return publisher_ls
    
    
    
    def crawl_process(self, n_page):
        self.item = OrderedDict(\
                       {'title' : [],
                        'text' : [],
                        'date' : [],
                        'publisher' : []
                       })
        
        for page_cnt in range(n_page):
            
            # 크롤링을 수행합니다.
            self.item['title'] += self._crawl_title()
            self.item['text'] += self._crawl_text()
            self.item['date'] += self._crawl_date()
            self.item['publisher'] += self._crawl_publisher()
            
            
            # 다음 페이지로 넘어갑니다.
            try:
                self.driver.find_element_by_css_selector('#main_pack > div.news.mynews.section._prs_nws > div.paging > a.next').click()
                time.sleep(1)
            except:
                return self.item
        
        return self.item

# %%
my_crawler = NaverNewsCrawler('삼성전자')

# %%
temp_dict = my_crawler.crawl_process(n_page= 5)

# %%
for key in temp_dict.keys():
    print(key, len(temp_dict[key]))
# Out:
# title 50
# text 50
# date 50
# publisher 50

# %%
data_df = pd.DataFrame(temp_dict)

# %%
data_df
# Out:
#                                              title  \
# 0            삼성 소프트웨어 인재 이어 창업 인재 키운다…500개 스타트업 육성
# 1                         3D 프린터 활용하는 삼성전자 C랩 과제원들
# 2                           C랩 성과 발표하는 이재일 삼성전자 상무
# 3             데일리안 오늘뉴스 종합평양행 초청장 전달 위해바티칸에 공들인 文대
# 4                   삼성전자 CO₂누출사고 원인 삼성하청업체 진술 엇갈린다
# 5   삼성전자 차량용 반도체 브랜드 Exynos Auto · ISOCELL Auto 출시
# 6                           누출 사고 삼성전자 기흥사업장 검찰 송치
# 7                   에이스침대 삼성전자와 콜라보 행사 하이마트쇼핑몰서 진행
# 8          경기도 이산화탄소 누출 사고 삼성전자 기흥사업장 소방시설법 위반으로 검
# 9                           삼성電 스페인 지랩스 인수5G 장비 강화
# 10                     Tech삼성 김치플러스 식품 보관의 차원을 바꾸다
# 11                          삼성전자 인도네시아 지진 피해 지역 지원
# 12                          누출 사고 삼성전자 기흥사업장 검찰 송치
# 13                    에이스침대·삼성전자 신혼부부 겨냥 콜래보레이션 진행
# 14             경기도 삼성전자 이산화탄소 누출 사고 검찰 송치과태료 4건 부과
# 15                         이재용 보험계약자의 돈으로 삼성을 지배하다
# 16                               삼성그룹주 펀드 약세장 속 선방
# 17         삼성바이오 유럽 공략 본격화매출 20조 휴미라 바이오시밀러 임랄디 시판
# 18                          삼성電 스페인 지랩스 인수5G 장비 강화
# 19             세계 첫 5G폰 타이틀 경쟁… 삼성 폴더블폰 위너 프로젝트 가동
# 20                  삼성 네트워크 솔루션기업 지랩스 인수…5G 경쟁력 강화
# 21                        외국인이 던진 삼성전자 사모은 개미들성적표는
# 22            이슈분석삼성 세대교체·신성장동력 육성 가속…이 부회장 재판이 변수
# 5   머니투데이 더리더 박영복 삼성전자가 자동차용 프로세서 브랜드 'Exynos Auto...  20181017           더리더
# 6     삼성전자 기흥사업장 이산화탄소 누출 사고에 대한 중간 조사 결과가 발표됐습니다....  20181017          MBC
# 7   ‘건강한 침실 공간’, ‘우리 아이 위한 침실’, ‘프리미엄 힐링’ 세 가지 테마로...  20181017        아시아투데이
# 8   사진은 지난 9월4일 사고가 발생한 삼성 기흥 반도체 공장 정문으로 삼성전자 자체 ...  20181017          경인일보
# 9   AI 기반 통신 품질 측정·분석 강화에 초점 삼성전자가 네트워크 서비스 분석 업체를...  20181017  ZDNet Korea
# 10   김치 냉장고 시장 변화… 4계절 사용가능한 프리미엄 냉장고 삼성전자의 2019년형...  20181017          동아일보
# 11  머니투데이 더리더 박영복 삼성전자는 지난 9월 인도네시아 술라웨시섬에서 발생한 지진...  20181017           더리더
# 12    삼성전자 기흥사업장 이산화탄소 누출 사고에 대한 중간 조사 결과가 발표됐습니다....  20181017          MBC
# 13   에이스침대가 삼성전자와 함께 하이마트쇼핑몰에서 10월 신혼부부를 겨냥한 콜래보레이...  20181017          이데일리
# 14    = 경기도는 지난달 4일 이산화탄소 누출 사고 사상자 3명을 낸 삼성전자 기흥사...  20181017          국제뉴스
# 15  여기서 눈여겨 볼 만한 지점은 삼성생명 총자산 258조 원 중 9.1%인 23조 원...  20181017         슬로우뉴스
# 16  ‘맏형’인 삼성전자 주가가 15일 기준 연초 이후 -13.4%로 부진했지만 삼성바이...  20181017          한국경제
# 17  삼성바이오로직스 관계자는 “콜옵션이 누락됐다고 지적한 당시에는 삼성바이오로직스는 비...  20181017          중앙일보
# 18  AI 기반 통신 품질 측정·분석 강화에 초점 삼성전자가 네트워크 서비스 분석 업체를...  20181017  ZDNet Korea
# 19  가트너에 따르면, 지난 2분기 기준 삼성전자가 19.3%로 1위를 차지했으며 이어 ...  20181017        디지털타임스
# 20  네트워크 서비스 품질 측정·최적화 시너지 기대 삼성전자는 차세대 네트워크 트래픽, ...  20181017          연합뉴스
# 21  특히 외국인이 집중적으로 팔아치웠던 삼성전자, 삼성전기 등의 종목을 공격적으로 사들...  20181017        디지털타임스
# 22  삼성은 지난해 최고 실적을 거둔 삼성전자 승진자 수가 200명을 넘는 등 인사 폭이...  20181017          전자신문
# 23    = 삼성전자가 멀티카메라장착 스마트폰 출시를 계기로 비메모리인 모바일용 이미지센...  20181017           뉴스핌
# 24   삼성전자가 지난 7월 AI와 로봇, 블록체인 분야 아이디어와 혁신 기술을 보유한 ...  20181017         벤처스퀘어
# 25  삼성전자와 SK하이닉스를 포함한 세계 주요 D램업체들이 미국과 중국의 무역분쟁으로 ...  20181017       비즈니스포스트
# 26  삼성전자의 3분기 영업이익이 17조를 넘어 사상 최대실적을 경신했다. 반도체는 그 ...  20181017         기자협회보
# 27  산업부 산하 3D융합산업협회장 맡아와 7개월간 공석이던 정보통신산업진흥원 원장에 김...  20181017   ZDNet Korea
